# %% [markdown]
# # Studying employees salary
#
# We have a database of salaries of employee. Our goal is to predict the salary giving other information on the employees. The challenge is that the data is complex and messy

# %%
import pandas as pd
train_df = pd.read_csv("challenge/train.csv")
train_df
# Out:
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (14,15) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         Unnamed: 0  AGY                                               NAME MI  \
# 0                1  781  TEXAS HIGHER EDUCATION COORDINATING BOARD     ...  C
# 1                2  101  SENATE                                        ...
# 2                3  241  COMPTROLLER OF PUBLIC ACCOUNTS, JUDICIARY SECT...  J
# 3                5  771  SCHOOL FOR THE BLIND AND VISUALLY IMPAIRED    ...  T
# 4                6  771  SCHOOL FOR THE BLIND AND VISUALLY IMPAIRED    ...  T
# ...            ...  ...                                                ... ..
# 112588      140720  308  STATE AUDITOR'S OFFICE                        ...  H
# 112589      140721  308  STATE AUDITOR'S OFFICE                        ...  T
# ...

# %% [markdown]
# We start by isolating our prediction target from the data

# %%
target = train_df['ANNUAL']
train_df.drop('ANNUAL', axis=1, inplace=True)

# %% [markdown]
# You must now:
# * Vectorize the data (turn it into a numpy array that scikit-learn can process)
# * Apply a prediction model
# * Cross-validate it to check the prediction accuracy
# * How about you try to inspect it, to know what is used to predict?
